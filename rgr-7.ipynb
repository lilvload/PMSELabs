# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
x = [0.531, 0.524, 0.541, 0.55, 0.559, 0.62, 0.632, 0.672, 0.682, 0.689, 0.692, 0.694, 0.698, 0.69, 0.71, 0.72, 0.725, 0.73]
y = [0.62, 0.58, 0.64, 0.65, 0.67, 0.68, 0.695, 0.699, 0.71, 0.715, 0.725, 0.781, 0.79, 0.795, 0.8, 0.81, 0.85, 0.86]

# %%
sns.scatterplot(x=x, y=y, label='Дані')
plt.title('Діаграма розсіювання: залежність між масою (X) і зростом (Y) дітей')
plt.legend()
plt.xlabel('Маса, кг')
plt.ylabel("Зрість, м")
# Out:
# Text(0, 0.5, 'Зрість, м')

# %%
sns.scatterplot(x=x, y=y, label='Дані')

x1 = np.linspace(0.531, 0.73, 100)
def y(x1):
    return 0.078 + x1
plt.plot(x1, y(x1), color='red', label='Функція регресії: y = 0.078 + x')
plt.title('Діаграма розсіювання: залежність між масою (X) і зростом (Y) дітей')
plt.legend()
plt.xlabel('Маса, кг')
plt.ylabel("Зрість, м")
# Out:
# Text(0, 0.5, 'Зрість, м')
